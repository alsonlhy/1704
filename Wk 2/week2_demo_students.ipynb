# %% [markdown]
# ## <font color="blue">Week 1 - Type conversion Recap</font>

# %%
# float to int 

a = 15.9
b = int(a)

print(a)
print(b)
# Out:
# 15.9
# 15

# %%
# string to int 

a = "15"
b = int(a)

print(a)
print(b)
# Out:
# 15
# 15

# %%
# string to float

a = "15.5"
b = float(a)

print(a)
print(b)
# Out:
# 15.5
# 15.5

# %%
# string to int (the number below the quotes MUST be an int number)

a = "15.5"
b = int(a)

print(a)
print(b)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 4
#       1 # string to int (the number below the quotes MUST be an int number)
#       3 a = "15.5"
# ----> 4 b = int(a)
#       6 print(a)
#       7 print(b)
#
# ValueError: invalid literal for int() with base 10: '15.5'

# %% [markdown]
# ## <font color="blue">Week 2 - Demo Notebook on Functions</font>

# %% [markdown]
# ## 1. Function Definition

# %%
# function that takes in 2 float numbers (num1 and num2) and 
# prints the sum of the 2 numbers

# %%
def print_sum(num1, num2):   
    num_sum = num1 + num2
    print(num_sum)

# %%
# Indentation in function definition is key!!!

# %%
def print_sum(num1, num2):   
    num_sum = num1 + num2
    print(num1)
    print(num_sum)
print("Hi!")

# %%
print_sum(1,2)

# 1 is ASSIGNED to num1, 2 is ASSIGNED to num2
# num_sum is a local variable, local to only print_sum
# Out:
# 3

# %% [markdown]
# ## 2. Function Call

# %% [markdown]
# ONLY after a function is defined, you can start calling that function

# %% [markdown]
# ### A. Docstring

# %%
# Written by the person who writes the function 
# to describe what to expect from the function

def print_sum(num1, num2):
    """
    
    """
    print(num1 + num2)

# %%
# Written by the person who writes the function

def print_sum(num1, num2):
    """
    The function calculates the sum of the two numbers num1 and num2.
    
    Parameters: 
        num1: the first number to add
        num2: the second number to add
        
    Returns:
        The sum of num1 and num2.  
    
    """
    print(num1 + num2)

# %%
# Function Call
print_sum(1,2.5)

# %%
help(print_sum)
# Out:
# Help on function print_sum in module __main__:
#
# print_sum(num1, num2)
#     The function calculates the sum of the two numbers num1 and num2.
#
#     Parameters:
#         num1: the first number to add
#         num2: the second number to add
#
#     Returns:
#         The sum of num1 and num2.

# %% [markdown]
# ### B. Parameters versus Arguments and notion of Scope or Lifetime

# %%
a = 5
b = 2
print_sum(a, b)

# a and b are arguments, only when in functions then they are parameters

# %%
print_sum(3.2, 2.5)
# Out:
# 5.7

# %%
print_sum("Hi", "Guys!")
# Out:
# HiGuys!

# %% [markdown]
# ```
# -> Remember that the function has to be defined BEFORE beeing called
# ```

# %% [markdown]
# ### C. Return Statement

# %% [markdown]
# You MAY or NOT have a `return` statement

# %%
def calculate_sum(num1, num2):
    num_sum = num1 + num2
    return num_sum

# %%
my_sum = calculate_sum(3.5, 8)

# %%
print('The sum of the 2 numbers is: ' + str(my_sum))
print('The sum of the 2 numbers is:' , my_sum)
print(f'The sum of the 2 numbers is: {my_sum}')
# Out:
# The sum of the 2 numbers is: 11.5
# The sum of the 2 numbers is: 11.5
# The sum of the 2 numbers is: 11.5

# %%
# Notion of local variable or scope of variable

# %%
# this code will create an error
print(num1, num2)

# %% [markdown]
# If NO `return` Statement:

# %%
def greet():
    print('hello!')
       
greet()
# Out:
# hello!

# %%
def greet():
    print('hello!')
    return None 
greet()
# Out:
# hello!

# %%
# Don't do the following (because meaningless!)

msg = greet()
print(msg)
# Out:
# hello!
# None

# %%
# Don't do this either
print(greet())
# Out:
# hello!
# None

# %% [markdown]
# ### D. Flow of Execution

# %%
# MSD

def add_numbers(a, b):
    a = a + 1
    b = b * 2
    return a + b

#after returning a + b, all parameters in func is destroyed, no longer exists. new a and new b and a + b is gone. once a + b is assigned then all destroyed

a = 1
b = 3
c = add_numbers(a, b)



print(a)
print(b)
print(c)
# Out:
# 8
# 1
# 3
# 8

# %%
def greet():
      get_name()
      print('Hi!', name)

def get_name():
      name = input('Enter your name: ')

greet()

# %% [markdown]
# ### E. Exercise on MSD (Homework for next week)

# %%
def do_trick1(a):
    a = a % 2
    return a

def do_trick2(x, y, z):
    x = x * 2
    y = z
    print(y, z + 1, x)
    
a = 3.5
b = 5
c = 8

do_trick2(a, b, c)
print(a, b, c)
d = do_trick1(b)

print(d)
print(a)

# USE Memory State Diagram, practice tracing the code (Tested)
