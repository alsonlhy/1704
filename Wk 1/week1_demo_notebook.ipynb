# %% [markdown]
# # <font color = blue>Learning Outcomes</font>
#
# At the end of this lesson, you should be able to:
# <ul>
# <li> Declare and initialise <b>variables</b>.</li>
#     <li> Know some basic data types in Python (<b>int</b>, <b>float</b>, <b>str</b>).</li>
# <li> Perform <b>type conversion</b>.</li>
# <li> Remember and apply the rules and naming conventions of variables.</li>
# <li> Use <b>print</b> to display something to the screen and use <b>input</b> to prompt the user.</li>
#     <li> Use effectively the various <b>arithmetic operators</b> in Python, and to apply proper <b>operator precedence</b> and <b>associativity</b> laws.</li>
#     <li> Understand and apply Python <b>naming rules</b> and <b>conventions</b> for variables. </li>
# <li> Include comments in your code.</li>
# </ul>

# %% [markdown]
# ### The following cell demonstrates variables assignment and MSD

# %%
# General idea of a variable
# How they are used to store data

# %%
a = 3
print(a)

# %%
a = 4
print(a)

# %%
a = a + 3
print(a)

# %%
# wrong statement - Be careful!
a + 2 = 5

# %%
# Correct statements
b = a + 3
print(b)

# %%
c = b
print(c)

# %%
c = 5
print(c)

# do you think the value of b has changed?

# %%
print(b)

# %% [markdown]
# ### What type of values can you put in a variable?

# %%
a = 8.2
print(a)
a = "SMU"
print(a)
c = 'SCIS'
print(c)

# %%
print(type(a))
print(type(b))
print(type(c))

# %%
d = 11
a1 = d
a2 = "d"

# %%
print(a1)
print(a2)

# %%
print(type(a1))
print(type(a2))

# %%
x = 3
x = x + 1
x += 1
print(x)

# %% [markdown]
# ## Let's elaborate on strings

# %% [markdown]
# ### a. Printing a string

# %%
# When you print a string, you don't' see the quotes
# a string is defined by single quotes or double quotes
s1 = 'hello'
s2 = "hello"
print(s1)
print(s2)

# %% [markdown]
# ![Hum.jpg](attachment:Hum.jpg)

# %%
# Note: a string can be empty
s1 = ''
s2 = ""

# %%
print("Hi")
print(s1)
print(s2)
print("Hi")

# %%
print('abcd')

# %%
print('1234')

# %%
print(type('1234'))

# %% [markdown]
# ### b. String Concatenation

# %%
a = "SMU"
b = "SCIS"
c = a + "-" + b
print(c)

# %%
print('abc' + '123')

# %%
print('abc' + 123)

# %% [markdown]
# ### c. Built-in function with strings: len( )

# %%
length = len("I love SMU")
print(length)

# %%
print(len(''))
print(len(' '))

# %% [markdown]
# ## Operators : +, -, /, %, //, **

# %% [markdown]
# ![arithmetic_operators.png](attachment:arithmetic_operators.png)

# %%
3 * 5

# %%
3 / 5

# %%
5 / 4

# %%
8 / 2

# %%
# can mix int and float
print(4 + 3.0)
print(10 - 2.5)
print(2 * 5)
print(2.5 * 4)
print(2.0 * 4)

# %% [markdown]
# ### with the following operators: +, -, *, %, //, **

# %% [markdown]
# ```
# int int -> int
# int float -> float
# float int -> float
# float float -> float
# ```

# %% [markdown]
# ### with the following operator:  /

# %% [markdown]
# always get a float!!!!
# ```
# int int -> float
# int float -> float
# float int -> float
# float float -> float
# ```

# %% [markdown]
# ### Floor division: quotient of the division

# %%
print(9 // 2)

# %% [markdown]
# 9 = 2 * 4 + 1

# %% [markdown]
# ### Modulo operator: remainder of the division

# %%
print(9 % 2)

# %% [markdown]
# 9 = 2 * 4 + 1

# %% [markdown]
# ### Exercise

# %%
# What is the expected output
print(5 // 3)
print(31 // 6)
print(4 // 5)

# %% [markdown]
# 5 = 3 * 1 + 2
# 31 = 6 * 5 + 1
# 4 = 5 * 0 + 4

# %%
# What is the expected output
print(5 % 3)
print(31 % 6)
print(4 % 5)

# %%
4 // 5

# %%
4 % 5

# %%
# Exponent

print(3 ** 4)

# %% [markdown]
# 3 * 3 * 3 * 3

# %%
print(2**7)

# %% [markdown]
# ### <font color="green">-> While doing operations, pay attention to the data type!!!</font>

# %% [markdown]
# ### Precedence and Association of Operators

# %% [markdown]
# ![operator_precedence.png](attachment:operator_precedence.png)

# %% [markdown]
# ### <font color="purple">Associativity : From LEFT to RIGHT except for ** which is from Right to LEFT</font>

# %% [markdown]
# #### Like in Mathematics... There are priorities in the order of the operators

# %%
print(5 + 3 * 4 - 2)

# %%
2 ** 2 ** 3

# %%
2 ** (2 ** 3)

# %%
(2 ** 2) ** 3

# %% [markdown]
# ## ICE - Q1

# %% [markdown]
# Exercises on expressions with arithmetic operators:

# %% [markdown]
# ### String Multiplication

# %%
s = '#'
print(s * 10)

# %% [markdown]
# ### Some `print()` built-in functions

# %%
# printing several variables in a single print statement 
a = 2
b = 4.5
c = 'hello'
print(a, b, c, a)
print(a)

# %%
print(2)
print("Good morning!")

# %%
print(len("I love SMU"))

# %%
print(type(a))
print(type(b))
print(type(c))

# %% [markdown]
# ### Other built-in functions : `min( )` and `max( )`

# %%
a_min = min(2.0, -10, 2, 4, 3, 777, -10.0)
print(a_min)

# %%
a_max = max(1, -10, 10000, 300, 3.5, 4000)
print(a_max)

# %% [markdown]
# ### `len()` built-in function

# %%
# len() applies to a string to know its length

print(len('Singapore Management University'))

# %%
# len() cannot be applied to a number
print(len(1234))

# %% [markdown]
# ### Another built in function : input( )

# %%
name = input('What is your name? ')

# %%
print('Hi ' + name + '!')

# %%
# You can use comma instead of concatenation

name = input('What is your name? ')
print('Hi', name, '!')

# %%
age = input("What’s your age? ")
print(age)
print(type(age))

# %%
# This code will not work
new_age = age + 1

# %% [markdown]
# ### Type conversion

# %% [markdown]
# #### `float` to `int` and `int` to `float`

# %%
x = 4.9
print(type(x))

# %%
# let's convert float to int

y = int(x)
print(y)   
print(type(y))

# %%
# let's convert int to float

z = float(y)

# %%
print(z)

# %% [markdown]
# ####  `string` to `int` or `string` to `float` and vice versa

# %%
# string to int
a = "100"
print(a)
print(type(a))

# %%
b = int(a)
print(b)
print(type(b))

# %%
# string to float
a = "100.5"
print(a)
print(type(a))

# %%
b = float(a)
print(b)
print(type(b))

# %% [markdown]
# #### Why do we need to convert `string` to numbers?

# %%
age = input("What’s your age? ")
print(age)
print(type(age))

# %%
next_year_age = age + 1
print("Next year you will be :", next_year_age)

# %%
# Solution 1

next_year_age = int(age) + 1
print("Next year you will be :", next_year_age)

# %%
# better solution

age = int(input("How old are you? "))
print(age)
print(type(age))

# %%
next_year_age = age + 1
print("Next year you will be :", next_year_age)

# %% [markdown]
# ## ICE - Q2

# %% [markdown]
# ### -> Go to elearn and download ICEs

# %% [markdown]
# ### BMI Calculator
#
# You have probably heard about the body mass index or BMI. The definition of BMI from Wikipedia can be found below:
#
# "The body mass index (BMI) or Quetelet index is a value derived from the mass (weight) and height of an individual. The BMI is defined as the body mass divided by the square of the body height, and is universally expressed in units of $\text{kg}/\text{m}^2$, resulting from mass in kilograms and height in metres."
#
# The formula to calculate BMI is also given below:
#
# $$\text{BMI} = \frac{\text{mass}}{\text{height}^2}$$
#
# Here mass is in kilograms and height is in metres.
#
# Write a piece of Python code that does the following:
#
# <ul>
#     <li>It prompts the user for his/her weight in kilograms.</li>
#     <li>It then prompts the user for his/her height in metres.</li>
#     <li>It calculates the BMI of this person and displays the BMI value to the screen.</li>
# </ul>
#
# A sample run of the code gives the following output:

# %% [markdown]
# ![week_1_bmi.png](attachment:week_1_bmi.png)

# %%
# put your code below

# %% [markdown]
# ### SUMMARY

# %%
print("Your bmi is " + str(bmi))  # you need to manage the spaces + conversion to str

# %%
print("Your BMI is", bmi)   # you don't need the conversion here and comma adds a space for you

# %%
print(f"Your BMI is {bmi}")

# %% [markdown]
# ## Rules for variable names

# %% [markdown]
# - Python <b>keywords</b> cannot be used as variable names.
# - A variable name cannot contain <b>any space</b>.
# - The <b>first character</b> of a variable name must be a <b>letter</b> or an <b>underscore</b> character (_)
# - The <b>remaining characters</b> must be a <b>letter</b>, a <b>digit</b>, or an <b>underscore</b> character.

# %%
import keyword
print(keyword.kwlist)

# %% [markdown]
# ## Naming conventions

# %% [markdown]
# - A variable name should be <b>meaningful</b> and represent what it stores. Usually variable names are nouns.
# - Use <b>lowercase letters</b> to name variables (unless the variable contains a constant).
# - If a variable name contains multiple words, use <b>underscore</b> characters to join the words.
#         - home_address
#         - first_name
#         - interest_rate

# %%
a_number = 2

# %% [markdown]
# ### To pay attention to that:

# %%
a = 15.5
b = int(a)

print(a)
print(b)

# %%
a = '15.5'
b = int(a)
print(a)
print(b)

# %%
import os
os.getcwd()
# Out:
# '/Users/joellee/Documents/Course COR-IS1704/AY2026-27-Term1/1. Content/Week 1/2. In-class Materials/1. Demo Notebook'
